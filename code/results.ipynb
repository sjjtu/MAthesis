# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
baseline = [0.9231200897867564,0.9376430205949656, 0.9085365853658537, 0.9228603603603603] # acc, prec, rec, f1
baseline_poll1 = [0.8378226711560045,0.8390486725663717, 0.8409090909090909, 0.8399778516057586]
baseline_poll2 = [0.8358585858585859,0.8480868075385494, 0.823170731707317, 0.8354430379746836]
baseline_poll5 = [0.7878787878787878,0.8018433179723502, 0.7716186252771619, 0.7864406779661017]

aemerf = [0.8425925925925926,0.8517260894170912, 0.8342572062084257, 0.8429011481377766]
aemerf_poll1 = [0.8479236812570146,0.8593394077448747, 0.8364745011086474, 0.847752808988764]
aemerf_poll2 = [0.8512906846240179,0.8699186991869918, 0.8303769401330376, 0.8496880317640386]
aemerf_poll5 = [0.8327721661054994,0.8463302752293578, 0.8181818181818182, 0.8320180383314545]

aedpmerf_eps1 = [0.8251964085297419,0.8411322934719815, 0.8070953436807096, 0.8237623762376238]
aedpmerf_eps1_poll1 = [0.8406285072951739,0.8511363636363637, 0.8303769401330376, 0.8406285072951738]
aedpmerf_eps1_poll2 = [0.8049943883277216,0.8116919617762788, 0.8004434589800443, 0.8060284677644433]
aedpmerf_eps1_poll5 = [0.8204264870931538,0.8183807439824945, 0.8292682926829268, 0.8237885462555066]

aedpmerf_eps05 = [0.8055555555555556,0.803386127799017, 0.815410199556541, 0.8093535075653371]
aedpmerf_eps05_poll1 = [0.8484848484848485,0.8615560640732265, 0.8348115299334812, 0.8479729729729729]
aedpmerf_eps05_poll2 = [0.8195847362514029,0.8322839152833429, 0.8059866962305987, 0.8189242466910729]
aedpmerf_eps05_poll5 = [0.8092031425364759,0.811529933481153, 0.811529933481153, 0.811529933481153]


aedpmerf_eps01 = [0.7586980920314254,0.7715765247410817, 0.7433481152993349, 0.7571993224167137]

aedpmerf_eps001 = [0.5148709315375982,0.5220978196817914, 0.4911308203991131, 0.5061411025421307]

aewgan = [0.7567340067340067,0.7592695074709463, 0.7605321507760532, 0.7599003046247577]
aewgan_poll1 = [0.7025813692480359,0.7002152852529602, 0.7211751662971175, 0.7105406881485526]
aewgan_poll2 = [0.7550505050505051,0.7658480868075386, 0.7433481152993349, 0.7544303797468355]
aewgan_poll5 = [0.7140852974186308,0.7223796033994334, 0.7067627494456763, 0.7144858503782572]

aewgan_eps35 = [0.7427048260381593,0.7495779403489027, 0.738359201773836, 0.7439262775760962]
aewgan_eps35_poll1 = [0.5333894500561167,0.5393634840871022, 0.5354767184035477, 0.5374130737134909]
aewgan_eps35_poll2 = [0.6972502805836139,0.704686617730096, 0.6917960088691796, 0.6981818181818181]
aewgan_eps35_poll5 = [0.6854657687991021,0.6984311446833237, 0.6662971175166297, 0.6819858156028369]

aewgan_eps25 = [0.7648709315375982,0.7731900452488688, 0.7577605321507761, 0.765397536394177]
aewgan_eps25_poll1 = [0.6094276094276094,0.6158605174353206, 0.6069844789356984, 0.611390284757119]
aewgan_eps25_poll2 = [0.5370370370370371,0.5426829268292683, 0.5426829268292683, 0.5426829268292683]
aewgan_eps25_poll5 = [0.7149270482603816,0.7218468468468469, 0.7106430155210643, 0.7162011173184358]

aewgan_eps5 = [0.5648148148148148,0.5712676056338029, 0.5620842572062085, 0.5666387259010898]

# %%
plt.figure(figsize=(10,10))
titles = ["Accuracy", "Precision", "Recall", "F1"]
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.hlines(baseline[i], 0, 1, linestyle="--", color="green")
    plt.hlines(aemerf[i],0 , 1, linestyle="--", color="red")
    plt.ylim([0.4, 1.0])
    plt.plot([0.001, 0.01, 0.5, 1.0], [aedpmerf_eps001[i], aedpmerf_eps01[i], aedpmerf_eps05[i], aedpmerf_eps1[i]], marker="o")
    
    plt.xlabel("Epsilon")
    plt.ylabel("Utility")
    plt.tight_layout()

plt.legend(["baseline", "AE-MERF", "AE-DPMERF"], bbox_to_anchor=(0.4, -0.1), ncol=3)
plt.show()

# %%
plt.figure(figsize=(15,15))
titles = ["Accuracy", "Precision", "Recall", "F1"]
for i in range(1):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.hlines(baseline[i], 0, 1, linestyle="--", color="green")
    plt.hlines(aemerf[i],0 , 1, linestyle="--", color="red")
    plt.ylim([0.4, 1.0])
    plt.plot([0.001, 0.01, 0.5, 1.0], [aedpmerf_eps001[i], aedpmerf_eps01[i], aedpmerf_eps05[i], aedpmerf_eps1[i]], marker="o")
    
    plt.xlabel("Epsilon")
    plt.ylabel("Utility")
    plt.tight_layout()

plt.legend(["baseline", "AE-MERF", "AE-DPMERF"], loc="lower center", ncol=3)
plt.show()

# %%
plt.figure(figsize=(10,10))
titles = ["Accuracy", "Precision", "Recall", "F1"]
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.hlines(baseline[i], 0, 35, linestyle="--", color="green")
    plt.hlines(aewgan[i],0 , 35, linestyle="--", color="red")
    plt.ylim([0.5, 1.0])
    plt.plot([5, 25,  35], [aewgan_eps5[i], aewgan_eps25[i], aewgan_eps35[i]], marker="o")
    
    plt.xlabel("Epsilon")
    plt.ylabel("Utility")
    plt.tight_layout()
    
plt.legend(["baseline", "AE-WGAN", "AE-dpWGAN"], bbox_to_anchor=(0.4, -0.1), ncol=3)
plt.show()

# %%
plt.figure(figsize=(15,15))
titles = ["Accuracy", "Precision", "Recall", "F1"]
for i in range(1):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.hlines(baseline[i], 0, 35, linestyle="--", color="green")
    plt.hlines(aewgan[i],0 , 35, linestyle="--", color="red")
    plt.ylim([0.5, 1.0])
    plt.plot([5, 25,  35], [aewgan_eps5[i], aewgan_eps25[i], aewgan_eps35[i]], marker="o")
    
    plt.xlabel("Epsilon")
    plt.ylabel("Utility")
    plt.tight_layout()
    
plt.legend(["baseline", "AE-WGAN", "AE-dpWGAN"],loc="lower center", ncol=3)
plt.show()

# %% [markdown]
# now with pollution

# %%
baseline_all = [baseline, baseline_poll1, baseline_poll2, baseline_poll5] # acc,prec,rec,f1
aemerf_all = [aemerf, aemerf_poll1, aemerf_poll2, aemerf_poll5]
aedpmerf_eps1_all = [aedpmerf_eps1, aedpmerf_eps1_poll1, aedpmerf_eps1_poll2, aedpmerf_eps1_poll5]
aedpmerf_eps05_all = [aedpmerf_eps05, aedpmerf_eps05_poll1, aedpmerf_eps05_poll2, aedpmerf_eps05_poll5]

# %%
plt.figure(figsize=(10,10))
titles = ["Accuracy", "Precision", "Recall", "F1"]
xaxis = [0, 1,2,5]
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.plot(xaxis, [c[i] for c in baseline_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aemerf_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps1_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps05_all], marker="o", linestyle="--")
    plt.xlabel("Contamination percentage")

plt.legend(["baseline", "AE-MERF", "AE-dpMERF $\epsilon=1$", "AE-dpMERF $\epsilon=0.5$"], loc="lower right", bbox_to_anchor=(0.8, -0.3), ncol=4)
plt.show()

# %%
plt.figure(figsize=(15,15))
titles = ["Accuracy", "Precision", "Recall", "F1"]
xaxis = [0, 1,2,5]
for i in range(1):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.plot(xaxis, [c[i] for c in baseline_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aemerf_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps1_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps05_all], marker="o", linestyle="--")
    plt.xlabel("Contamination percentage")

plt.legend(["baseline", "AE-MERF", "AE-dpMERF $\epsilon=1$", "AE-dpMERF $\epsilon=0.5$"], ncol=1)
plt.show()

# %%
plt.figure(figsize=(10,10))
titles = ["Accuracy", "Precision", "Recall", "F1"]
xaxis = [0, 1,2,5]
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.plot(xaxis, [c[i] for c in baseline_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aemerf_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps1_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps05_all], marker="o", linestyle="--", alpha=0.3)
    plt.xlabel("Contamination percentage")

plt.legend(["baseline", "AE-MERF", "AE-dpMERF $\epsilon=1$", "AE-dpMERF $\epsilon=0.5$"], loc="lower right", bbox_to_anchor=(0.8, -0.3), ncol=4)
plt.show()

# %%
plt.figure(figsize=(15,15))
titles = ["Accuracy", "Precision", "Recall", "F1"]
xaxis = [0, 1,2,5]
for i in range(1):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.plot(xaxis, [c[i] for c in baseline_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aemerf_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps1_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps05_all], marker="o", linestyle="--", alpha=0.3)
    plt.xlabel("Contamination percentage")

plt.legend(["baseline", "AE-MERF", "AE-dpMERF $\epsilon=1$", "AE-dpMERF $\epsilon=0.5$"], ncol=1)
plt.show()

# %%
plt.figure(figsize=(10,10))
titles = ["Accuracy", "Precision", "Recall", "F1"]
xaxis = [0, 1,2,5]
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.plot(xaxis, [c[i] for c in baseline_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aemerf_all], marker="o", linestyle="--", alpha=1)
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps1_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps05_all], marker="o", linestyle="--", alpha=0.3)
    plt.xlabel("Contamination percentage")

plt.legend(["baseline", "AE-MERF", "AE-dpMERF $\epsilon=1$", "AE-dpMERF $\epsilon=0.5$"], loc="lower right", bbox_to_anchor=(0.8, -0.3), ncol=4)
plt.show()

# %%
plt.figure(figsize=(15,15))
titles = ["Accuracy", "Precision", "Recall", "F1"]
xaxis = [0, 1,2,5]
for i in range(1):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.plot(xaxis, [c[i] for c in baseline_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aemerf_all], marker="o", linestyle="--", alpha=1)
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps1_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps05_all], marker="o", linestyle="--", alpha=0.3)
    plt.xlabel("Contamination percentage")

plt.legend(["baseline", "AE-MERF", "AE-dpMERF $\epsilon=1$", "AE-dpMERF $\epsilon=0.5$"], ncol=1)
plt.show()

# %%
plt.figure(figsize=(10,10))
titles = ["Accuracy", "Precision", "Recall", "F1"]
xaxis = [0, 1,2,5]
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.plot(xaxis, [c[i] for c in baseline_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aemerf_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps1_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps05_all], marker="o", linestyle="--")
    plt.xlabel("Contamination percentage")

plt.legend(["baseline", "AE-MERF", "AE-dpMERF $\epsilon=1$", "AE-dpMERF $\epsilon=0.5$"], loc="lower right", bbox_to_anchor=(0.8, -0.3), ncol=4)
plt.show()

# %%
plt.figure(figsize=(15,15))
titles = ["Accuracy", "Precision", "Recall", "F1"]
xaxis = [0, 1,2,5]
for i in range(1):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.plot(xaxis, [c[i] for c in baseline_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aemerf_all], marker="o", linestyle="--", alpha=0.3)
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps1_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aedpmerf_eps05_all], marker="o", linestyle="--")
    plt.xlabel("Contamination percentage")

plt.legend(["baseline", "AE-MERF", "AE-dpMERF $\epsilon=1$", "AE-dpMERF $\epsilon=0.5$"], ncol=1)
plt.show()

# %%
aewgan_all = [aewgan, aewgan_poll1, aewgan_poll2, aewgan_poll5]
aewgan_eps35_all = [aewgan_eps35, aewgan_eps35_poll1, aewgan_eps35_poll2, aewgan_eps35_poll5]
aewgan_eps25_all = [aewgan_eps25, aewgan_eps25_poll1, aewgan_eps25_poll2, aewgan_eps25_poll5]

# %%
plt.figure(figsize=(10,10))
titles = ["Accuracy", "Precision", "Recall", "F1"]
xaxis = [0, 1,2,5]
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.title(titles[i])
    plt.plot(xaxis, [c[i] for c in baseline_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aewgan_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aewgan_eps35_all], marker="o", linestyle="--")
    plt.plot(xaxis, [c[i] for c in aewgan_eps25_all], marker="o", linestyle="--")
    plt.xlabel("Contamination percentage")

plt.legend(["baseline", "aewgan", "aewgan eps35", "aewgan eps25"], loc="lower right", bbox_to_anchor=(0.8, -0.3), ncol=4)
